# %%
# %run bonus.py
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/09 17:18:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/11/09 17:18:06 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Reading Online Retail data from: /home/jovyan/shared/midterm/Online Retail.csv
# Row count after cleaning:
# 397884
#
# === Part 1: UDF for order size ===
# +----------+---------+------------------+----------+
# |CustomerID|InvoiceNo|order_value       |order_size|
# +----------+---------+------------------+----------+
# |17420     |536385   |130.85            |Medium    |
# |13767     |536395   |507.8800000000001 |Large     |
# ...
