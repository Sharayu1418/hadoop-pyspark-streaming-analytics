# %%
# %run q2_ecommerce_analysis.py
# Out:
# 25/11/09 18:19:48 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Spark session initialized successfully
#
# Loading dataset from: /home/jovyan/shared/midterm/Online Retail.csv
# Initial record count: 541909
# Record count after filtering: 397884
# Removed 144025 records (26.6%)
#
# ...
# PART A: BASIC AGGREGATIONS
# ...
#
# ...
# PART B: WINDOW FUNCTIONS
# ...
#
# ...
# PART A RESULTS: Customer Aggregations
# ...
# CustomerId | num_orders | total_spent | avg_order_value | top_product
# ----------------------------------------------------------------------
# +----------+----------+-----------+---------------+-----------+
# |CustomerID|num_orders|total_spent|avg_order_value|top_product|
# +----------+----------+-----------+---------------+-----------+
# |12346     |1         |77183.6    |77183.6        |23166      |
# |12347     |7         |4310.0     |615.71         |22375      |
# |12348     |4         |1797.24    |449.31         |POST       |
# ...
